# %%
from backend.services.gemma_service import GemmaService
service = GemmaService()

with open("test_images/pothole.png", "rb") as f:
    image = f.read()

result = service.analyze_image(image)

print(result)
# Out:
# issue_type='Pothole' description='The road surface is heavily damaged with multiple large potholes visible across the asphalt.' confidence=0.99

# %%
from backend.services.gemma_service import GemmaService
service = GemmaService()

with open("test_images/garbage.jpg", "rb") as f:
    image = f.read()

result = service.analyze_image(image)

print(result)
# Out:
# issue_type='Garbage' description='There is a large amount of uncollected garbage piled up along the roadside and in the foreground.' confidence=0.99
